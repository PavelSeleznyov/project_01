# %%
# Задание:
# Выведите на консоль с помощью индексации строки, последовательно: первый трек, последний, второй, второй с конца
# Нельзя переопределять my_favorite_songs и запятая не должна выводиться.
# решение:
# добавил tabs в блокноте к каждому символу в строке
# далее использовал Excel - вставил строку с табами (разбил на ячейки) и пронумеровал (вручную)
my_favorite_songs = 'Waste a Moment, Staying\' Alive, A Sorta Fairytale, Start Me Up, New Salvation'
str(my_favorite_songs)
print(my_favorite_songs[0:14])
print(my_favorite_songs[-13::])
print(my_favorite_songs[16:30])
print(my_favorite_songs[-26:-15])
# Out:
# Waste a Moment
# New Salvation
# Staying' Alive
# Start Me Up
